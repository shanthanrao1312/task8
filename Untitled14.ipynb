# %% [markdown]
# # Name : Shanthan Rao

# %% [markdown]
# # Task 8 : Timeline Analysis : Covid-19

# %%
#importing all the required libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import matplotlib.colors as mcolors

# %%
#Reading the Data
covid_data = pd.read_csv('owid-covid-data.csv');
covid_data.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          1.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          1.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          1.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          2.0        1.0
# 9      AFG      Asia  Afghanistan  2020-03-04          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
# 5               0.143           NaN         NaN                  0.0  ...
# 6               0.143           NaN         NaN                  0.0  ...
# 7               0.000           NaN         NaN                  0.0  ...
# 8               0.143           NaN         NaN                  0.0  ...
# 9               0.429           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
# 5        1803.987              NaN                597.029
# 6        1803.987              NaN                597.029
# 7        1803.987              NaN                597.029
# 8        1803.987              NaN                597.029
# 9        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
# 5                 9.59             NaN           NaN                  37.746
# 6                 9.59             NaN           NaN                  37.746
# 7                 9.59             NaN           NaN                  37.746
# 8                 9.59             NaN           NaN                  37.746
# 9                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
# 5                         0.5            64.83                    0.511
# 6                         0.5            64.83                    0.511
# 7                         0.5            64.83                    0.511
# 8                         0.5            64.83                    0.511
# 9                         0.5            64.83                    0.511
#
# [10 rows x 59 columns]

# %%
# Analyzing the rows and columns count of the dataset
covid_data.shape
# Out:
# (86869, 59)

# %%
# Analyzing the data types of all the attributes present and their count
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86869 entries, 0 to 86868
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               86869 non-null  object
#  1   continent                              82686 non-null  object
#  2   location                               86869 non-null  object
#  3   date                                   86869 non-null  object
#  4   total_cases                            84664 non-null  float64
#  5   new_cases                              84662 non-null  float64
#  6   new_cases_smoothed                     83661 non-null  float64
#  7   total_deaths                           74936 non-null  float64
#  8   new_deaths                             75094 non-null  float64
#  9   new_deaths_smoothed                    83661 non-null  float64
#  10  total_cases_per_million                84207 non-null  float64
#  11  new_cases_per_million                  84205 non-null  float64
#  12  new_cases_smoothed_per_million         83209 non-null  float64
#  13  total_deaths_per_million               74492 non-null  float64
#  14  new_deaths_per_million                 74650 non-null  float64
#  15  new_deaths_smoothed_per_million        83209 non-null  float64
#  16  reproduction_rate                      70034 non-null  float64
#  17  icu_patients                           8830 non-null   float64
#  18  icu_patients_per_million               8830 non-null   float64
#  19  hosp_patients                          10999 non-null  float64
#  20  hosp_patients_per_million              10999 non-null  float64
#  21  weekly_icu_admissions                  801 non-null    float64
#  22  weekly_icu_admissions_per_million      801 non-null    float64
#  23  weekly_hosp_admissions                 1392 non-null   float64
#  24  weekly_hosp_admissions_per_million     1392 non-null   float64
#  25  new_tests                              39642 non-null  float64
#  26  total_tests                            39345 non-null  float64
#  27  total_tests_per_thousand               39345 non-null  float64
#  28  new_tests_per_thousand                 39642 non-null  float64
#  29  new_tests_smoothed                     45462 non-null  float64
#  30  new_tests_smoothed_per_thousand        45462 non-null  float64
#  31  positive_rate                          43692 non-null  float64
#  32  tests_per_case                         43099 non-null  float64
#  33  tests_units                            46938 non-null  object
#  34  total_vaccinations                     10100 non-null  float64
#  35  people_vaccinated                      9415 non-null   float64
#  36  people_fully_vaccinated                7035 non-null   float64
#  37  new_vaccinations                       8570 non-null   float64
#  38  new_vaccinations_smoothed              16154 non-null  float64
#  39  total_vaccinations_per_hundred         10100 non-null  float64
#  40  people_vaccinated_per_hundred          9415 non-null   float64
#  41  people_fully_vaccinated_per_hundred    7035 non-null   float64
#  42  new_vaccinations_smoothed_per_million  16154 non-null  float64
#  43  stringency_index                       73485 non-null  float64
#  44  population                             86312 non-null  float64
#  45  population_density                     80869 non-null  float64
#  46  median_age                             78218 non-null  float64
#  47  aged_65_older                          77326 non-null  float64
#  48  aged_70_older                          77780 non-null  float64
#  49  gdp_per_capita                         78573 non-null  float64
#  50  extreme_poverty                        53477 non-null  float64
#  51  cardiovasc_death_rate                  79156 non-null  float64
#  52  diabetes_prevalence                    80344 non-null  float64
#  53  female_smokers                         62000 non-null  float64
#  54  male_smokers                           61087 non-null  float64
#  55  handwashing_facilities                 39767 non-null  float64
#  56  hospital_beds_per_thousand             72211 non-null  float64
#  57  life_expectancy                        82452 non-null  float64
#  58  human_development_index                79032 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 39.1+ MB

# %%
# Identifying the columns present
covid_data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# Descripting of the numerical attributes present in the dataset
covid_data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  8.466400e+04   84662.000000        83661.000000  7.493600e+04
# mean   8.563349e+05    5929.960136         5909.639958  2.364604e+04
# std    5.914187e+06   37293.716340        36606.072173  1.400248e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    9.700000e+02       2.000000            7.000000  4.600000e+01
# 50%    1.082300e+04      71.000000           87.000000  3.230000e+02
# 75%    1.153232e+05     776.000000          808.571000  3.139250e+03
# max    1.576882e+08  905992.000000       826374.286000  3.283031e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  75094.000000         83661.000000             84207.000000
# mean     140.506365           124.584843             10465.895801
# std      767.594790           703.146103             19963.370294
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               207.876500
# 50%        2.000000             1.286000              1426.159000
# 75%       18.000000            13.857000             10286.724500
# max    17906.000000         14435.714000            173506.762000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           84205.000000                    83209.000000
# mean               74.906470                       75.011972
# std               176.508546                      149.460021
# min             -2153.437000                     -276.825000
# 25%                 0.196000                        1.182000
# 50%                 7.759000                       10.244000
# 75%                69.000000                       77.032000
# max              8652.658000                     2648.773000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              74492.000000  ...    78573.000000     53477.000000
# mean                 232.313072  ...    19145.959443        13.352916
# std                  407.006389  ...    19835.251110        19.943980
# min                    0.001000  ...      661.240000         0.100000
# 25%                    6.862750  ...     4466.507000         0.500000
# 50%                   41.124000  ...    12951.839000         2.200000
# 75%                  250.009250  ...    27216.445000        21.200000
# max                 2950.618000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           79156.000000         80344.000000    62000.000000
# mean              257.874687             7.822401       10.524409
# std               118.789584             3.981497       10.404257
# min                79.370000             0.990000        0.100000
# 25%               167.295000             5.290000        1.900000
# 50%               242.648000             7.110000        6.300000
# 75%               329.635000            10.080000       19.300000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  61087.000000            39767.000000                72211.000000
# mean      32.660467               50.903886                    3.029621
# std       13.474563               31.762556                    2.462853
# min        7.700000                1.188000                    0.100000
# 25%       21.600000               20.859000                    1.300000
# 50%       31.400000               49.839000                    2.400000
# 75%       41.100000               83.241000                    3.861000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     82452.000000             79032.000000
# mean         73.167068                 0.727093
# std           7.549355                 0.150069
# min          53.280000                 0.394000
# 25%          67.920000                 0.602000
# 50%          74.530000                 0.748000
# 75%          78.730000                 0.848000
# max          86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
#Checking for count of all the unique values present for each attribute
covid_data.nunique()
# Out:
# iso_code                                   219
# continent                                    6
# location                                   219
# date                                       494
# total_cases                              46020
# new_cases                                11800
# new_cases_smoothed                       22565
# total_deaths                             17560
# new_deaths                                2781
# new_deaths_smoothed                       6272
# total_cases_per_million                  65534
# new_cases_per_million                    37468
# new_cases_smoothed_per_million           42248
# total_deaths_per_million                 40723
# new_deaths_per_million                    7201
# new_deaths_smoothed_per_million           8533
# reproduction_rate                          372
# icu_patients                              2383
# icu_patients_per_million                  5023
# hosp_patients                             4661
# hosp_patients_per_million                 8330
# weekly_icu_admissions                      601
# weekly_icu_admissions_per_million          597
# weekly_hosp_admissions                    1242
# weekly_hosp_admissions_per_million        1238
# new_tests                                21477
# total_tests                              38370
# total_tests_per_thousand                 33808
# new_tests_per_thousand                    7062
# new_tests_smoothed                       24187
# new_tests_smoothed_per_thousand           7247
# positive_rate                              561
# tests_per_case                            5166
# tests_units                                  4
# total_vaccinations                        9711
# people_vaccinated                         8976
# people_fully_vaccinated                   6532
# new_vaccinations                          7638
# new_vaccinations_smoothed                10552
# total_vaccinations_per_hundred            3569
# people_vaccinated_per_hundred             2912
# people_fully_vaccinated_per_hundred       1698
# new_vaccinations_smoothed_per_million     5903
# stringency_index                           176
# population                                 217
# population_density                         200
# median_age                                 134
# aged_65_older                              184
# aged_70_older                              182
# gdp_per_capita                             190
# extreme_poverty                             75
# cardiovasc_death_rate                      188
# diabetes_prevalence                        141
# female_smokers                             110
# male_smokers                               125
# handwashing_facilities                      95
# hospital_beds_per_thousand                 100
# life_expectancy                            195
# human_development_index                    152
# dtype: int64

# %%
# Checking for count of NULL values for each column 
covid_data.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4183
# location                                     0
# date                                         0
# total_cases                               2205
# new_cases                                 2207
# new_cases_smoothed                        3208
# total_deaths                             11933
# new_deaths                               11775
# new_deaths_smoothed                       3208
# total_cases_per_million                   2662
# new_cases_per_million                     2664
# new_cases_smoothed_per_million            3660
# total_deaths_per_million                 12377
# new_deaths_per_million                   12219
# new_deaths_smoothed_per_million           3660
# reproduction_rate                        16835
# icu_patients                             78039
# icu_patients_per_million                 78039
# hosp_patients                            75870
# hosp_patients_per_million                75870
# weekly_icu_admissions                    86068
# weekly_icu_admissions_per_million        86068
# weekly_hosp_admissions                   85477
# weekly_hosp_admissions_per_million       85477
# new_tests                                47227
# total_tests                              47524
# total_tests_per_thousand                 47524
# new_tests_per_thousand                   47227
# new_tests_smoothed                       41407
# new_tests_smoothed_per_thousand          41407
# positive_rate                            43177
# tests_per_case                           43770
# tests_units                              39931
# total_vaccinations                       76769
# people_vaccinated                        77454
# people_fully_vaccinated                  79834
# new_vaccinations                         78299
# new_vaccinations_smoothed                70715
# total_vaccinations_per_hundred           76769
# people_vaccinated_per_hundred            77454
# people_fully_vaccinated_per_hundred      79834
# new_vaccinations_smoothed_per_million    70715
# stringency_index                         13384
# population                                 557
# population_density                        6000
# median_age                                8651
# aged_65_older                             9543
# aged_70_older                             9089
# gdp_per_capita                            8296
# extreme_poverty                          33392
# cardiovasc_death_rate                     7713
# diabetes_prevalence                       6525
# female_smokers                           24869
# male_smokers                             25782
# handwashing_facilities                   47102
# hospital_beds_per_thousand               14658
# life_expectancy                           4417
# human_development_index                   7837
# dtype: int64

# %%
# Continents in terms of occurence of covid cases on basis of iso_codes
covid_data.continent.value_counts()[0:10]
# Out:
# Africa           22687
# Europe           20854
# Asia             20617
# North America    10529
# South America     5331
# Oceania           2668
# Name: continent, dtype: int64

# %%
# Analyzing cases worldwide 
dataset = covid_data[covid_data['date']=='2020-11-15']
dataset = dataset[~dataset['location'].isin(['World','International'])]
dataset.head(10)
# Out:
#       iso_code      continent             location        date  total_cases  \
# 265        AFG           Asia          Afghanistan  2020-11-15      43240.0
# 716   OWID_AFR            NaN               Africa  2020-11-15    1976022.0
# 1155       ALB         Europe              Albania  2020-11-15      27830.0
# 1594       DZA         Africa              Algeria  2020-11-15      67679.0
# 2027       AND         Europe              Andorra  2020-11-15       5872.0
# 2442       AGO         Africa               Angola  2020-11-15      13451.0
# 2942       ATG  North America  Antigua and Barbuda  2020-11-15        134.0
# 3436       ARG  South America            Argentina  2020-11-15    1310491.0
# 3870       ARM           Asia              Armenia  2020-11-15     117337.0
# 4383  OWID_ASI            NaN                 Asia  2020-11-15   15118723.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 265       205.0             154.429        1620.0        12.0
# 716     12570.0           13308.857       47362.0       296.0
# 1155      597.0             517.714         623.0        11.0
# 1594      860.0             804.000        2154.0        15.0
# 2027      147.0              69.857          76.0         1.0
# 2442       77.0             145.429         322.0         0.0
# 2942        0.0               0.429           4.0         0.0
# 3436     5645.0            9758.429       35436.0       129.0
# 3870     1482.0            1559.000        1763.0        25.0
# 4383    81910.0           93796.714      266621.0      1463.0
#
#       new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 265                 7.857  ...        1803.987              NaN
# 716               286.000  ...             NaN              NaN
# 1155                9.143  ...       11803.431              1.1
# 1594               15.143  ...       13913.839              0.5
# 2027                0.143  ...             NaN              NaN
# 2442                2.143  ...        5819.495              NaN
# 2942                0.143  ...       21490.943              NaN
# 3436              268.000  ...       18933.907              0.6
# 3870               29.143  ...        8787.580              1.8
# 4383             1556.571  ...             NaN              NaN
#
#       cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 265                 597.029                 9.59             NaN
# 716                     NaN                  NaN             NaN
# 1155                304.195                10.08             7.1
# 1594                278.364                 6.73             0.7
# 2027                109.135                 7.97            29.0
# 2442                276.045                 3.94             NaN
# 2942                191.511                13.17             NaN
# 3436                191.032                 5.50            16.2
# 3870                341.010                 7.11             1.5
# 4383                    NaN                  NaN             NaN
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 265            NaN                  37.746                        0.50
# 716            NaN                     NaN                         NaN
# 1155          51.2                     NaN                        2.89
# 1594          30.4                  83.741                        1.90
# 2027          37.8                     NaN                         NaN
# 2442           NaN                  26.664                         NaN
# 2942           NaN                     NaN                        3.80
# 3436          27.7                     NaN                        5.00
# 3870          52.1                  94.043                        4.20
# 4383           NaN                     NaN                         NaN
#
#       life_expectancy  human_development_index
# 265             64.83                    0.511
# 716               NaN                      NaN
# 1155            78.57                    0.795
# 1594            76.88                    0.748
# 2027            83.73                    0.868
# 2442            61.15                    0.581
# 2942            77.02                    0.778
# 3436            76.67                    0.845
# 3870            75.09                    0.776
# 4383              NaN                      NaN
#
# [10 rows x 59 columns]

# %%
# looking at different locations
covid_data["location"].value_counts()
# Out:
# Argentina       494
# Mexico          494
# Thailand        491
# Peru            489
# Taiwan          479
#                ...
# Saint Helena     66
# Aruba            40
# Curacao          39
# Tonga            13
# Nauru             8
# Name: location, Length: 219, dtype: int64

# %%
# covid cases in india

india=covid_data[covid_data["location"]=="India"]

# %%
india.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 35737      IND      Asia    India  2020-01-30          1.0        1.0
# 35738      IND      Asia    India  2020-01-31          1.0        0.0
# 35739      IND      Asia    India  2020-02-01          1.0        0.0
# 35740      IND      Asia    India  2020-02-02          2.0        1.0
# 35741      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 35737                 NaN           NaN         NaN                  NaN  ...
# 35738                 NaN           NaN         NaN                  NaN  ...
# 35739                 NaN           NaN         NaN                  NaN  ...
# 35740                 NaN           NaN         NaN                  NaN  ...
# 35741                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 35737        6426.674             21.2                 282.28
# 35738        6426.674             21.2                 282.28
# 35739        6426.674             21.2                 282.28
# 35740        6426.674             21.2                 282.28
# 35741        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 35737                10.39             1.9          20.6
# 35738                10.39             1.9          20.6
# 35739                10.39             1.9          20.6
# 35740                10.39             1.9          20.6
# 35741                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 35737                   59.55                        0.53            69.66
# 35738                   59.55                        0.53            69.66
# 35739                   59.55                        0.53            69.66
# 35740                   59.55                        0.53            69.66
# 35741                   59.55                        0.53            69.66
#
#        human_development_index
# 35737                    0.645
# 35738                    0.645
# 35739                    0.645
# 35740                    0.645
# 35741                    0.645
#
# [5 rows x 59 columns]

# %%
#Data Visualization
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=india)
plt.show()

# %%
india_last_5_days=india.tail()

# %%
# total cases last 5 days

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
# total test per day

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_tests",data=india)
plt.show()

# %%
# total test last 5 days

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
# covid cases in Brazil

brazil=covid_data[covid_data["location"]=="Brazil"]

# %%
brazil.head()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 11137      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 11138      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 11139      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 11140      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 11141      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 11137                 NaN           NaN         NaN                  NaN  ...
# 11138                 NaN           NaN         NaN                  NaN  ...
# 11139                 NaN           NaN         NaN                  NaN  ...
# 11140                 NaN           NaN         NaN                  NaN  ...
# 11141                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 11137       14103.452              3.4                177.961
# 11138       14103.452              3.4                177.961
# 11139       14103.452              3.4                177.961
# 11140       14103.452              3.4                177.961
# 11141       14103.452              3.4                177.961
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 11137                 8.11            10.1          17.9
# 11138                 8.11            10.1          17.9
# 11139                 8.11            10.1          17.9
# 11140                 8.11            10.1          17.9
# 11141                 8.11            10.1          17.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 11137                     NaN                         2.2            75.88
# 11138                     NaN                         2.2            75.88
# 11139                     NaN                         2.2            75.88
# 11140                     NaN                         2.2            75.88
# 11141                     NaN                         2.2            75.88
#
#        human_development_index
# 11137                    0.765
# 11138                    0.765
# 11139                    0.765
# 11140                    0.765
# 11141                    0.765
#
# [5 rows x 59 columns]

# %%
brazil.tail()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 11570      BRA  South America   Brazil  2021-05-04   14856888.0    77359.0
# 11571      BRA  South America   Brazil  2021-05-05   14930183.0    73295.0
# 11572      BRA  South America   Brazil  2021-05-06   15003563.0    73380.0
# 11573      BRA  South America   Brazil  2021-05-07   15082449.0    78886.0
# 11574      BRA  South America   Brazil  2021-05-08   15145879.0    63430.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 11570           59332.143      411588.0      2966.0             2366.571  ...
# 11571           58413.429      414399.0      2811.0             2316.286  ...
# 11572           58983.571      416949.0      2550.0             2251.857  ...
# 11573           60491.143      419114.0      2165.0             2190.429  ...
# 11574           59986.286      421316.0      2202.0             2125.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 11570       14103.452              3.4                177.961
# 11571       14103.452              3.4                177.961
# 11572       14103.452              3.4                177.961
# 11573       14103.452              3.4                177.961
# 11574       14103.452              3.4                177.961
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 11570                 8.11            10.1          17.9
# 11571                 8.11            10.1          17.9
# 11572                 8.11            10.1          17.9
# 11573                 8.11            10.1          17.9
# 11574                 8.11            10.1          17.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 11570                     NaN                         2.2            75.88
# 11571                     NaN                         2.2            75.88
# 11572                     NaN                         2.2            75.88
# 11573                     NaN                         2.2            75.88
# 11574                     NaN                         2.2            75.88
#
#        human_development_index
# 11570                    0.765
# 11571                    0.765
# 11572                    0.765
# 11573                    0.765
# 11574                    0.765
#
# [5 rows x 59 columns]

# %%
brazil_last_5_days=brazil.tail()

# %%
# total cases last 5 days

sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %%
# understanding cases of india,china and japan

india_japan_china=covid_data[(covid_data["location"]=="India") | (covid_data["location"]=="China") | (covid_data["location"]=="Japan")]

# %%
# total cases 

sns.set(rc={"figure.figsize":(15,10)})
sns.barplot(x="location",y="total_cases",data=india_japan_china,hue="date")
plt.show()

# %%
# understanding cases of germany and spain


germany_spain=covid_data[(covid_data["location"]=="Germany") | (covid_data["location"]=="Spain")]

# %%
# total cases 

sns.set(rc={"figure.figsize":(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain,hue="date")
plt.show()

# %%
# getting latset data

last_day_cases=covid_data[(covid_data["date"]=="2020-12-18")]
last_day_cases
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 298         AFG      Asia  Afghanistan  2020-12-18      49621.0      243.0
# 749    OWID_AFR       NaN       Africa  2020-12-18    2469647.0    19320.0
# 1188        ALB    Europe      Albania  2020-12-18      52004.0      580.0
# 1627        DZA    Africa      Algeria  2020-12-18      94371.0      438.0
# 2060        AND    Europe      Andorra  2020-12-18       7519.0       53.0
# ...         ...       ...          ...         ...          ...        ...
# 85028       VNM      Asia      Vietnam  2020-12-18       1410.0        3.0
# 85501  OWID_WRL       NaN        World  2020-12-18   75789960.0   720462.0
# 85895       YEM      Asia        Yemen  2020-12-18       2087.0        0.0
# 86312       ZMB    Africa       Zambia  2020-12-18      18575.0       71.0
# 86727       ZWE    Africa     Zimbabwe  2020-12-18      12047.0      181.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 298               215.000        2030.0         5.0               12.143  ...
# 749             17818.286       58310.0       496.0              378.286  ...
# 1188              734.429        1066.0        11.0               12.714  ...
# 1627              464.286        2647.0         7.0               10.286  ...
# 2060               40.429          80.0         1.0                0.286  ...
# ...                   ...           ...         ...                  ...  ...
# 85028               2.714          35.0         0.0                0.000  ...
# 85501          645864.429     1680145.0     12789.0            11574.286  ...
# 85895               0.714         606.0         0.0                0.000  ...
# 86312              59.143         373.0         4.0                1.143  ...
# 86727             126.429         316.0         2.0                1.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 298          1803.987              NaN                597.029
# 749               NaN              NaN                    NaN
# 1188        11803.431              1.1                304.195
# 1627        13913.839              0.5                278.364
# 2060              NaN              NaN                109.135
# ...               ...              ...                    ...
# 85028        6171.884              2.0                245.465
# 85501       15469.207             10.0                233.070
# 85895        1479.147             18.8                495.003
# 86312        3689.251             57.5                234.499
# 86727        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 298                   9.59             NaN           NaN
# 749                    NaN             NaN           NaN
# 1188                 10.08           7.100        51.200
# 1627                  6.73           0.700        30.400
# 2060                  7.97          29.000        37.800
# ...                    ...             ...           ...
# 85028                 6.00           1.000        45.900
# 85501                 8.51           6.434        34.635
# 85895                 5.35           7.600        29.200
# 86312                 3.94           3.100        24.700
# 86727                 1.82           1.600        30.700
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 298                    37.746                       0.500            64.83
# 749                       NaN                         NaN              NaN
# 1188                      NaN                       2.890            78.57
# 1627                   83.741                       1.900            76.88
# 2060                      NaN                         NaN            83.73
# ...                       ...                         ...              ...
# 85028                  85.847                       2.600            75.40
# 85501                  60.130                       2.705            72.58
# 85895                  49.542                       0.700            66.12
# 86312                  13.938                       2.000            63.89
# 86727                  36.791                       1.700            61.49
#
#        human_development_index
# 298                      0.511
# 749                        NaN
# 1188                     0.795
# 1627                     0.748
# 2060                     0.868
# ...                        ...
# 85028                    0.704
# 85501                    0.737
# 85895                    0.470
# 86312                    0.584
# 86727                    0.571
#
# [198 rows x 59 columns]

# %%
# sorting date w.r.t to total cases

max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code      continent          location        date  total_cases  \
# 85501  OWID_WRL            NaN             World  2020-12-18   75789960.0
# 26676  OWID_EUR            NaN            Europe  2020-12-18   21074550.0
# 57531  OWID_NAM            NaN     North America  2020-12-18   20251704.0
# 4416   OWID_ASI            NaN              Asia  2020-12-18   19629928.0
# 82684       USA  North America     United States  2020-12-18   17574950.0
# ...         ...            ...               ...         ...          ...
# 84135       VAT         Europe           Vatican  2020-12-18         27.0
# 71166       SLB        Oceania   Solomon Islands  2020-12-18         17.0
# 49523       MHL        Oceania  Marshall Islands  2020-12-18          4.0
# 66627       WSM        Oceania             Samoa  2020-12-18          2.0
# 83706       VUT        Oceania           Vanuatu  2020-12-18          1.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 85501   720462.0          645864.429     1680145.0     12789.0
# 26676   244541.0          212044.714      486362.0      5713.0
# 57531   277539.0          243892.857      468006.0      3933.0
# 4416    100404.0          102874.429      319870.0      1371.0
# 82684   251969.0          221072.714      318521.0      2967.0
# ...          ...                 ...           ...         ...
# 84135        0.0               0.000           NaN         NaN
# 71166        0.0               0.000           NaN         NaN
# 49523        0.0               0.000           NaN         NaN
# 66627        0.0               0.000           NaN         NaN
# 83706        0.0               0.000           NaN         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 85501            11574.286  ...       15469.207             10.0
# 26676             4998.429  ...             NaN              NaN
# 57531             3530.714  ...             NaN              NaN
# 4416              1446.429  ...             NaN              NaN
# 82684             2712.286  ...       54225.446              1.2
# ...                    ...  ...             ...              ...
# 84135                0.000  ...             NaN              NaN
# 71166                0.000  ...        2205.923             25.1
# 49523                0.000  ...        3819.202              NaN
# 66627                0.000  ...        6021.557              NaN
# 83706                0.000  ...        2921.909             13.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 85501                233.070                 8.51           6.434
# 26676                    NaN                  NaN             NaN
# 57531                    NaN                  NaN             NaN
# 4416                     NaN                  NaN             NaN
# 82684                151.089                10.79          19.100
# ...                      ...                  ...             ...
# 84135                    NaN                  NaN             NaN
# 71166                459.780                18.68             NaN
# 49523                557.793                30.53             NaN
# 66627                348.977                 9.21          16.700
# 83706                546.300                12.02           2.800
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 85501        34.635                  60.130                       2.705
# 26676           NaN                     NaN                         NaN
# 57531           NaN                     NaN                         NaN
# 4416            NaN                     NaN                         NaN
# 82684        24.600                     NaN                       2.770
# ...             ...                     ...                         ...
# 84135           NaN                     NaN                         NaN
# 71166           NaN                  35.890                       1.400
# 49523           NaN                  82.502                       2.700
# 66627        38.100                     NaN                         NaN
# 83706        34.500                  25.209                         NaN
#
#        life_expectancy  human_development_index
# 85501            72.58                    0.737
# 26676              NaN                      NaN
# 57531              NaN                      NaN
# 4416               NaN                      NaN
# 82684            78.86                    0.926
# ...                ...                      ...
# 84135            75.12                      NaN
# 71166            73.00                    0.567
# 49523            73.70                    0.704
# 66627            73.32                    0.715
# 83706            70.47                    0.609
#
# [198 rows x 59 columns]

# %%
# top 5 countries with maximum case
max_cases_country[1:6]
# Out:
#        iso_code      continent        location        date  total_cases  \
# 26676  OWID_EUR            NaN          Europe  2020-12-18   21074550.0
# 57531  OWID_NAM            NaN   North America  2020-12-18   20251704.0
# 4416   OWID_ASI            NaN            Asia  2020-12-18   19629928.0
# 82684       USA  North America   United States  2020-12-18   17574950.0
# 27148  OWID_EUN            NaN  European Union  2020-12-18   13969915.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 26676   244541.0          212044.714      486362.0      5713.0
# 57531   277539.0          243892.857      468006.0      3933.0
# 4416    100404.0          102874.429      319870.0      1371.0
# 82684   251969.0          221072.714      318521.0      2967.0
# 27148   157984.0          133727.286      331199.0      4093.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 26676             4998.429  ...             NaN              NaN
# 57531             3530.714  ...             NaN              NaN
# 4416              1446.429  ...             NaN              NaN
# 82684             2712.286  ...       54225.446              1.2
# 27148             3516.000  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 26676                    NaN                  NaN             NaN
# 57531                    NaN                  NaN             NaN
# 4416                     NaN                  NaN             NaN
# 82684                151.089                10.79            19.1
# 27148                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 26676           NaN                     NaN                         NaN
# 57531           NaN                     NaN                         NaN
# 4416            NaN                     NaN                         NaN
# 82684          24.6                     NaN                        2.77
# 27148           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 26676              NaN                      NaN
# 57531              NaN                      NaN
# 4416               NaN                      NaN
# 82684            78.86                    0.926
# 27148              NaN                      NaN
#
# [5 rows x 59 columns]

# %%
# plot on bar plot

sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="date")
plt.show()

# %% [markdown]
# # THANK YOU
